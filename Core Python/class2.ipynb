# %%
literals,variables and identifers 
literals-->they are fixed values in a program 
different types
1)Numeric literals 
2)boolean literals --True or False
3)characters literlas --they are unicode characeters 
a='5' 
string a="akshatha"
4)specials --None-->to specify null values
ex:a=10;
varible
the conatiner that holds a value 
ex:a=10 
identifer 
print 
-----
print(shift+tab)
Signature: print(*args, sep=' ', end='\n', file=None, flush=False)
Docstring:
Prints the values to a stream, or to sys.stdout by default.

sep
  string inserted between values, default a space.
end
  string appended after the last value, default a newline.
file
  a file-like object (stream); defaults to the current sys.stdout.
flush
  whether to forcibly flush the stream.
Type:      builtin_function_or_method 

Python operators 
----------------
what is operator?
an expression which gives result 
a=5
b=5
a+b=10
a,b=operands 
+=operator 
10=values 
1)Arithmetic operator --->+,-,*,/,%,**
    / -->quotient
    % -->remaainder
2)Assignment operator --->"=",+=,-=,*=,/=,%=,**=
3)comparision operator --->==,!=,>,<,>=,<=
4)Logical operator ----->AND,OR and Not
AND operator 
--it any have any number of statements if all the statements are true then only it will return true else it will return false
--and operator 
exa:
A    B   A and B
T    T    T
T    F    F
F    T    F
F    F    F 
OR operator 
-if any one statement is also true then it will return true and if all the given statements is false then only it will return false
A    B   A or B
T    T    T
T    F    T
F    T    T
F    F    F 

Not
--if give true it will return false and if your give false it will return true 
A  not A
T   F
F   T
5)Bitwise operator ----->&(Bitwsie and) 
                         |(Bitwise or)
                        ~(Bitwise not)
                           >>(right shift)
                           <<(left shift)

1)&(Bitwise and) 
    5 & 2
6)special operator 
                           1)identity 
                            2)membership

# %%
#variables 
a=1.2
print("variable->",a)
print("string->",'akshatha')
# Out:
# variable-> 1.2
# string-> akshatha

# %%
#end
print("hello",end='😊')
print("good moring")
# Out:
# hello😊good moring

# %%
#sep 
print("""New year""",2024,"""bye bye""",sep=".")
#sep 
print("New year",2024,'bye bye',sep=" ")
# Out:
# New year.2024.bye bye
# New year 2024 bye bye

# %%
#file 
#file_path=r'C:\Users\GT -0510\Desktop\Python(9 to 11)\class1.ipynb'
with open("class1.ipynb") as file:
    a=file.read()
    print(a)
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "id": "685934b6-d459-4024-91f9-1f8ba9284a94",
#    "metadata": {},
#    "source": [
#     "Introduction to Python "
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "fdc9588d-92b2-45c7-b8fa-42cf0b999f09",
#    "metadata": {},
#    "source": [
#     "2hr--session \r\n",
#     "30min--15min\r\n",
#     "notes--by the end of session \r\n",
#     "\r\n",
#     "Introduction to Python \r\n",
#     "----------------------\r\n",
#     "who designed?\r\n",
#     "what is python?\r\n",
#     "where to use python?\r\n",
#     "why python?\r\n",
#     "how to use python?\r\n",
#     "--Guido van Rossum \r\n",
#     "ABC--project \r\n",
#     "\r\n",
#     "1989-1991-->python 0.9.0\r\n",
#     "feature-Exception handling(errors),functions and core datatype(list,strings and dict) \r\n",
#     "\r\n",
#     "1994-python 10 \r\n",
#     "features-modules(reuse of code)\r\n",
#     "new datastructure \"lambda\"\r\n",
#     "\r\n",
# ...

# %%
#Arithmetic operator 
a=10
b=20
print("Addition",a+b)
print("sub",a-b)
print("mult",a*b)
print("div",a/b)
print("mod",a%b)
print("expo",a**b)
# Out:
# Addition 30
# sub -10
# mult 200
# div 0.5
# mod 10
# expo 100000000000000000000

# %%
#Assignment arithmatic operator
a=10
print("the value of a before addition",a)
b=5
print("the value of b before addition",b)
a+=b
print("the value of a After addition",a)
# Out:
# the value of a before addition 10
# the value of b before addition 5
# the value of a After addition 15

# %%
#comparision operator 
#result Boolean values (True or False)
a=5
b=2
print("a==b->",a==b)
print("a!=b->",a!=b)
print('a>b->',a>b)
print('a<b->',a<b) 
print('a>=b->',a>=b)
print('a<=b->',a<=b)
# Out:
# a==b-> False
# a!=b-> True
# a>b-> True
# a<b-> False
# a>=b-> True
# a<=b-> False

# %%
#logical operators 
print(True and True)
print(True or True)
print(not True)
# Out:
# True
# True
# False

# %%
#bitwise operator 
print(5&2)
print(5|2)
#140 & 3 
#55 | 39
# Out:
# 0
# 7

# %%
#bitwise not
~8
print(~8)
print(~4)

#~164 
#~99
# Out:
# -9
# -5

# %% [markdown]
# ## Assignment
#
# 1) try to get in print statement for python file and text file
#
# 2) 56 & 8
#
# 3) 67 | 9
#
# 4) ~92
#
# 5) ~321

# %% [markdown]
# ### 1) try to get in print statement for python file and text file

# %%
# print statement for python file

with open(r"E:\Data Science Course\Core Python\class1.ipynb") as file:
    a = file.read()
    print(a)
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "id": "685934b6-d459-4024-91f9-1f8ba9284a94",
#    "metadata": {},
#    "source": [
#     "Introduction to Python "
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "fdc9588d-92b2-45c7-b8fa-42cf0b999f09",
#    "metadata": {},
#    "source": [
#     "2hr--session \r\n",
#     "30min--15min\r\n",
#     "notes--by the end of session \r\n",
#     "\r\n",
#     "Introduction to Python \r\n",
#     "----------------------\r\n",
#     "who designed?\r\n",
#     "what is python?\r\n",
#     "where to use python?\r\n",
#     "why python?\r\n",
#     "how to use python?\r\n",
#     "--Guido van Rossum \r\n",
#     "ABC--project \r\n",
#     "\r\n",
#     "1989-1991-->python 0.9.0\r\n",
#     "feature-Exception handling(errors),functions and core datatype(list,strings and dict) \r\n",
#     "\r\n",
#     "1994-python 10 \r\n",
#     "features-modules(reuse of code)\r\n",
#     "new datastructure \"lambda\"\r\n",
#     "\r\n",
# ...

# %%
# print statement for python file

with open(r"E:\Data Science Course\Core Python\class1.txt") as file:
    a = file.read()
    print(a)
# Out:
# 2hr--session
# 30min--15min
# notes--by the end of session
#
# Introduction to Python
# ----------------------
# who designed?
# what is python?
# where to use python?
# why python?
# how to use python?
# --Guido van Rossum
# ABC--project
#
# 1989-1991-->python 0.9.0
# feature-Exception handling(errors),functions and core datatype(list,strings and dict)
#
# 1994-python 10
# features-modules(reuse of code)
# new datastructure "lambda"
#
# 2000-python 2.0
# feature-garbage collection system (it will help manage memory automatically),
# list comprehensions
#
# 2008--python 3.0
# --better handling of Unicode
# --better redundance
#
# 2010--python 3.2
# --very powerfull framework for writing asynchronous
# --connection with web server
#
# 2014--python 3.4
# --multiple tasks were simultaneously conducted
#
# 2015-python 3.5
# --"async" and "await"
#
# 2018-python 3.7
# --boilerplate code can also be included
#
# 2020-python 3.10
# --walrus operator(:=)
#
# 2022-python 3.11
# ...

# %% [markdown]
# ### 2) 56 & 8

# %%
print('56 & 8 =',56&8)
# Out:
# 56 & 8 = 8

# %% [markdown]
# ### 3) 67 | 9

# %%
print('67 | 9 =',67|9)
# Out:
# 67 | 9 = 75

# %% [markdown]
# ### 4) ~92

# %%
print('Negation(~) of 92 =',~92)
# Out:
# Negation(~) of 92 = -93

# %% [markdown]
# ### 5) ~321

# %%
print('Negation(~) of 321 =',~321)
# Out:
# Negation(~) of 321 = -322
